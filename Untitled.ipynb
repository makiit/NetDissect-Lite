# %%
import torch
import torchvision

# %%
import settings
from loader.model_loader import loadmodel
from feature_operation import hook_feature,FeatureOperator
from visualize.report import generate_html_summary
from util.clean import clean

# %%
print(settings.DATASET)
# Out:
# places365

# %%
import os
from torch.autograd import Variable as V
from PIL import Image
# from scipy.misc import imresize
import numpy as np
import torch
import settings
import time
import util.upsample as upsample
import util.vecquantile as vecquantile
import multiprocessing.pool as pool
from loader.data_loader import load_csv
from loader.data_loader import SegmentationData, SegmentationPrefetcher

features_blobs = []
def hook_feature(module, input, output):
#     print("Hooking module named ",module.name)
    features_blobs.append(output.data.cpu().numpy())

# %%
# model_file = "chekpoints_small/resnet18-200-regular.pth"
model_file = "zoo/resnet18_places365.pth.tar"
# path = "iter200"
# fo = FeatureOperator(path)
print("Loading model file ",model_file)
model = loadmodel(hook_feature,model_file)
# model = loadmodel(hook_feature,model_file)
# checkpoint = torch.load(model_file)
# model = torchvision.models.__dict__[settings.MODEL](num_classes=settings.NUM_CLASSES)
# model.conv1 = torch.nn.Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# model.maxpool = torch.nn.Identity()
# state_dict = checkpoint["state_dict"]
# model.load_state_dict(state_dict)
# model.cuda()
# model.eval()
# Out:
# Loading model file  zoo/resnet18_places365.pth.tar

# %%
from loader.data_loader import load_csv
import settings
from loader.data_loader import SegmentationData, SegmentationPrefetcher
print(settings.DATA_DIRECTORY)
data = SegmentationData(settings.DATA_DIRECTORY, categories=settings.CATAGORIES)
loader = SegmentationPrefetcher(data,categories=['image'],once=True,batch_size=settings.BATCH_SIZE)
mean = [109.5388,118.6897,124.6901]
# Out:
# dataset/broden1_224
# /home/makhan/NetDissect-Lite/loader/data_loader.py:151: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[list(np.indices(arr.shape)) + [arr]] = 1

# %%
num_batches = (len(loader.indexes) + loader.batch_size - 1) / loader.batch_size
print(num_batches)
print(model._modules.get("layer4"))
# model._modules.get("layer4").register_forward_hook(hook_feature)
print(len(loader.indexes))
# Out:
# 3957.5
# Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 63305

# %%
maxfeatures = [None] * len(settings.FEATURE_NAMES) #Max activation in the channel (broden_size,no.of channels)
wholefeatures = [None] * len(settings.FEATURE_NAMES) #All the activations (broden_size,no.of channels,h,w)
features_size = [None] * len(settings.FEATURE_NAMES)
memmap=True
for batch_idx,batch in enumerate(loader.tensor_batches(bgr_mean=mean)):
        del features_blobs[:]
        torch.cuda.empty_cache()
        input = batch[0]
        batch_size = len(input)
        print('extracting feature from batch %d / %d' % (batch_idx+1, num_batches))
        input = torch.from_numpy(input[:, ::-1, :, :].copy())
        input.div_(255.0 * 0.224)
        if settings.GPU:
            input = input.cuda()
        input_var = V(input,volatile=True)
        logit = model.forward(input_var)  
#         if(batch_idx>2):break
        #Initializing the feature variables
        print("Feature Blobs length ",len(features_blobs))
        print("First blob",np.shape(features_blobs[0]))
        if maxfeatures[0] is None:
            # initialize the feature variable
            for i, feat_batch in enumerate(features_blobs):
                print("Initializing %d"%i)
                size_features = (len(loader.indexes), feat_batch.shape[1])
                if memmap:
                    maxfeatures[i] = np.memmap('Places_Max_features.mmap',dtype=float,mode='w+',shape=size_features)
                else:
                    maxfeatures[i] = np.zeros(size_features)
                    
        #Initializing the all feature variable
        if len(feat_batch.shape) == 4 and wholefeatures[0] is None:
            # initialize the feature variable
            for i, feat_batch in enumerate(features_blobs):
                size_features = (
                len(loader.indexes), feat_batch.shape[1], feat_batch.shape[2], feat_batch.shape[3])
                features_size[i] = size_features
                if memmap:
                    wholefeatures[i] = np.memmap('Places_Whole_features.mmap', dtype=float, mode='w+', shape=size_features)
                else:
                    wholefeatures[i] = np.zeros(size_features)
                    
        np.save("test_feature_size.npy", features_size)
        start_idx = batch_idx*settings.BATCH_SIZE
        end_idx = min((batch_idx+1)*settings.BATCH_SIZE, len(loader.indexes))
        for i, feat_batch in enumerate(features_blobs):
            if len(feat_batch.shape) == 4:
                wholefeatures[i][start_idx:end_idx] = feat_batch
                maxfeatures[i][start_idx:end_idx] = np.max(np.max(feat_batch,3),2)
            elif len(feat_batch.shape) == 3:
                maxfeatures[i][start_idx:end_idx] = np.max(feat_batch, 2)
            elif len(feat_batch.shape) == 2:
                maxfeatures[i][start_idx:end_idx] = feat_batch
#     if len(feat_batch.shape) == 2:
#         wholefeatures = maxfeatures
#     return wholefeatures,maxfeatures
# Out:
# extracting feature from batch 1 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# Initializing 0
# extracting feature from batch 2 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# /tmp/ipykernel_9701/3932491975.py:15: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_var = V(input,volatile=True)
# extracting feature from batch 4 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 5 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 6 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 7 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 8 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 9 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 10 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 11 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 12 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 13 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 14 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 15 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 16 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 17 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 18 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 19 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 20 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 21 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 22 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 23 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 24 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 25 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 26 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 27 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 28 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 29 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 30 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 31 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 32 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 33 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 34 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 35 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 36 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 37 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 38 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 39 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 40 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 41 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 42 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 43 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 44 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 45 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 46 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 47 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 48 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 49 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 50 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 51 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 52 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 53 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 54 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 55 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 56 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 57 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 58 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 59 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 60 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 61 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 62 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 63 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 64 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 65 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 66 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 67 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 68 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 69 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 70 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 71 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 72 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 73 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 74 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 75 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 76 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 77 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 78 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 79 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 80 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 81 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 82 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 83 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 84 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 85 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 86 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 87 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 88 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 89 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 90 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 91 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 92 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 93 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 94 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 95 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 96 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 97 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 98 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 99 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 100 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 101 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 102 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 103 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 104 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 105 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 106 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 107 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 108 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 109 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 110 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 111 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 112 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 113 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 114 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 115 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 116 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 117 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 118 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 119 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 120 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 121 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 122 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 123 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 124 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 125 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 126 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 127 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 128 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 129 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 130 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 131 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 132 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 133 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 134 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 135 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 136 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 137 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 138 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 139 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 140 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 141 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 142 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 143 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 144 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 145 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 146 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 147 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 148 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 149 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 150 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 151 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 152 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 153 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 154 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 155 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 156 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 157 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 158 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 159 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 160 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 161 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 162 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 163 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 164 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 165 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 166 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 167 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 168 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 169 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 170 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 171 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 172 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 173 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 174 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 175 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 176 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 177 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 178 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 179 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 180 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 181 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 182 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 183 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 184 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 185 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 186 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 187 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 188 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 189 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 190 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 191 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 192 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 193 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 194 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 195 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 196 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 197 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 198 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 199 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 200 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 201 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 202 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 203 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 204 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 205 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 206 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 207 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 208 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 209 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 210 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 211 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 212 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 213 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 214 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 215 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 216 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 217 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 218 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 219 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 220 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 221 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 222 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 223 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 224 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 225 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 226 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 227 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 228 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 229 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 230 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 231 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 232 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 233 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 234 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 235 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 236 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 237 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 238 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 239 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 240 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 241 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 242 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 243 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 244 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 245 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 246 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 247 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 248 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 249 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 250 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 251 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 252 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 253 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 254 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 255 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 256 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 257 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 258 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 259 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 260 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 261 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 262 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 263 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 264 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 265 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 266 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 267 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 268 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 269 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 270 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 271 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 272 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 273 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 274 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 275 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 276 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 277 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 278 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 279 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 280 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 281 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 282 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 283 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 284 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 285 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 286 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 287 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 288 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 289 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 290 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 291 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 292 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 293 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 294 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 295 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 296 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 297 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 298 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 299 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 300 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 301 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 302 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 303 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 304 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 305 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 306 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 307 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 308 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 309 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 310 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 311 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 312 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 313 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 314 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 315 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 316 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 317 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 318 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 319 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 320 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 321 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 322 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 323 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 324 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 325 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 326 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 327 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 328 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 329 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 330 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 331 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 332 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 333 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 334 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 335 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 336 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 337 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 338 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 339 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 340 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 341 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 342 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 343 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 344 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 345 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 346 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 347 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 348 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 349 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 350 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 351 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 352 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 353 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 354 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 355 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 356 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 357 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 358 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 359 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 360 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 361 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 362 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 363 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 364 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 365 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 366 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 367 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 368 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 369 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 370 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 371 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 372 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 373 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 374 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 375 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 376 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 377 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 378 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 379 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 380 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 381 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 382 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 383 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 384 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 385 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 386 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 387 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 388 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 389 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 390 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 391 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 392 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 393 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 394 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 395 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 396 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 397 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 398 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 399 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 400 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 401 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 402 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 403 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 404 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 405 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 406 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 407 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 408 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 409 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 410 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 411 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 412 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 413 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 414 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 415 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 416 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 417 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 418 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 419 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 420 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 421 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 422 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 423 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 424 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 425 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 426 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 427 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 428 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 429 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 430 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 431 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 432 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 433 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 434 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 435 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 436 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 437 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 438 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 439 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 440 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 441 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 442 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 443 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 444 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 445 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 446 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 447 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 448 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 449 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 450 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 451 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 452 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 453 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 454 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 455 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 456 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 457 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 458 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 459 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 460 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 461 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 462 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 463 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 464 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 465 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 466 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 467 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 468 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 469 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 470 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 471 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 472 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 473 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 474 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 475 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 476 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 477 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 478 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 479 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 480 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 481 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 482 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 483 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 484 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 485 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 486 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 487 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 488 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 489 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 490 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 491 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 492 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 493 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 494 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 495 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 496 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 497 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 498 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 499 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 500 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 501 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 502 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 503 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 504 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 505 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 506 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 507 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 508 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 509 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 510 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 511 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 512 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 513 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 514 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 515 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 516 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 517 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 518 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 519 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 520 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 521 / 3957
# Feature Blobs length  1
# ...
# extracting feature from batch 3786 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3787 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3788 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3789 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3790 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3791 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3792 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3793 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3794 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3795 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3796 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3797 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3798 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3799 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3800 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3801 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3802 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3803 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3804 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3805 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3806 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3807 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3808 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3809 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3810 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3811 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3812 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3813 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3814 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3815 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3816 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3817 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3818 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3819 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3820 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3821 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3822 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3823 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3824 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3825 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3826 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3827 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3828 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3829 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3830 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3831 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3832 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3833 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3834 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3835 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3836 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3837 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3838 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3839 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3840 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3841 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3842 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3843 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3844 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3845 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3846 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3847 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3848 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3849 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3850 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3851 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3852 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3853 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3854 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3855 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3856 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3857 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3858 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3859 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3860 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3861 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3862 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3863 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3864 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3865 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3866 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3867 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3868 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3869 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3870 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3871 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3872 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3873 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3874 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3875 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3876 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3877 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3878 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3879 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3880 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3881 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3882 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3883 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3884 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3885 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3886 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3887 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3888 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3889 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3890 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3891 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3892 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3893 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3894 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3895 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3896 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3897 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3898 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3899 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3900 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3901 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3902 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3903 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3904 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3905 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3906 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3907 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3908 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3909 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3910 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3911 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3912 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3913 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3914 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3915 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3916 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3917 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3918 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3919 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3920 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3921 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3922 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3923 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3924 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3925 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3926 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3927 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3928 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3929 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3930 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3931 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3932 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3933 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3934 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3935 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3936 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3937 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3938 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3939 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3940 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3941 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3942 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3943 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3944 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3945 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3946 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3947 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3948 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3949 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3950 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3951 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3952 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3953 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3954 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3955 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3956 / 3957
# Feature Blobs length  1
# First blob (16, 512, 7, 7)
# extracting feature from batch 3957 / 3957
# Feature Blobs length  1
# First blob (9, 512, 7, 7)

# %%
feature_size = np.load("test_feature_size.npy")
print(feature_size)
wholefeatures = np.memmap("Places_Whole_features.mmap", dtype=float,mode='r', shape=tuple(feature_size[0]))
# Out:
# [[63305   512     7     7]]

# %%
print(np.shape(wholefeatures))
fo = FeatureOperator("Places_test")
thresh = fo.quantile_threshold(wholefeatures)
# Out:
# (63305, 512, 7, 7)
# /home/makhan/NetDissect-Lite/loader/data_loader.py:151: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[list(np.indices(arr.shape)) + [arr]] = 1
# calculating quantile threshold
# Processing quantile index 0: 0.000000 24403223.263422
# Processing quantile index 64: 1553.877559 1553.976508
# Processing quantile index 128: 1816.514674 2185.992085
# Processing quantile index 192: 1933.165219 2218.034902
# Processing quantile index 256: 2013.233205 2298.878597
# Processing quantile index 320: 2051.471499 2220.144538
# Processing quantile index 384: 2112.556055 2482.089118
# Processing quantile index 448: 2142.798877 2344.148315
# Processing quantile index 512: 604.851878 100.405405
# Processing quantile index 576: 661.677563 2663.737234
# Processing quantile index 640: 712.851585 2345.356702
# Processing quantile index 704: 760.139109 2257.999159
# Processing quantile index 768: 802.113555 2043.152128
# Processing quantile index 832: 839.652617 1915.275631
# Processing quantile index 896: 530.324136 91.605660
# Processing quantile index 960: 559.612054 2467.101594
# Processing quantile index 1024: 585.840515 1972.760221
# Processing quantile index 1088: 539.947725 239.616108
# Processing quantile index 1152: 565.015859 2681.083638
# Processing quantile index 1216: 589.670983 2748.420236
# Processing quantile index 1280: 613.873974 2788.476264
# Processing quantile index 1344: 531.312423 143.992825
# Processing quantile index 1408: 552.837668 3704.857581
# Processing quantile index 1472: 573.036597 2920.824513
# Processing quantile index 1536: 538.045915 223.773415
# Processing quantile index 1600: 556.129959 2876.350988
# Processing quantile index 1664: 573.970748 2898.933627
# Processing quantile index 1728: 591.357931 2784.340217
# Processing quantile index 1792: 487.796621 85.154618
# Processing quantile index 1856: 498.442635 1281.645178
# Processing quantile index 1920: 481.337526 241.248228
# Processing quantile index 1984: 494.448947 2704.666606
# Processing quantile index 2048: 476.012980 220.799326
# Processing quantile index 2112: 488.815248 3507.401364
# Processing quantile index 2176: 501.098520 2934.618856
# Processing quantile index 2240: 495.450565 358.186641
# Processing quantile index 2304: 507.207980 2993.726228
# Processing quantile index 2368: 490.072486 221.129635
# Processing quantile index 2432: 501.069103 2951.526763
# Processing quantile index 2496: 496.904289 377.629738
# Processing quantile index 2560: 507.443718 2936.545049
# Processing quantile index 2624: 517.764663 2777.167498
# Processing quantile index 2688: 487.516168 143.586688
# Processing quantile index 2752: 497.045992 2776.851483
# Processing quantile index 2816: 493.479526 377.122553
# Processing quantile index 2880: 502.708140 2837.734087
# Processing quantile index 2944: 511.811381 2764.725119
# Processing quantile index 3008: 497.433182 217.004868
# Processing quantile index 3072: 505.668411 2278.874432
# Processing quantile index 3136: 501.507700 359.516426
# Processing quantile index 3200: 510.368730 3802.201926
# Processing quantile index 3264: 497.679274 221.864720
# Processing quantile index 3328: 505.426795 2452.719711
# Processing quantile index 3392: 513.324226 2737.935967
# Processing quantile index 3456: 509.037657 352.865611
# Processing quantile index 3520: 516.939003 3194.823451
# Processing quantile index 3584: 473.079459 83.487661
# Processing quantile index 3648: 479.938321 2551.595069
# Processing quantile index 3712: 480.541787 517.641563
# Processing quantile index 3776: 476.603653 323.050737
# Processing quantile index 3840: 483.535714 3408.487791
# Processing quantile index 3904: 484.034957 516.000746
# Processing quantile index 3968: 480.697196 338.367148
# Processing quantile index 4032: 487.128013 2856.091332
# Processing quantile index 4096: 486.551084 452.768296
# Processing quantile index 4160: 478.626605 234.348526
# Processing quantile index 4224: 485.044615 3777.588742
# Processing quantile index 4288: 485.243247 498.722621
# Processing quantile index 4352: 491.192429 2750.757855
# Processing quantile index 4416: 488.241596 346.637142
# Processing quantile index 4480: 488.615192 515.851015
# Processing quantile index 4544: 494.643875 3628.584931
# Processing quantile index 4608: 490.758394 315.050668
# Processing quantile index 4672: 491.149754 521.067963
# Processing quantile index 4736: 496.574707 2563.828961
# Processing quantile index 4800: 488.862526 227.454520
# Processing quantile index 4864: 489.231188 518.560539
# Processing quantile index 4928: 494.820761 3757.652981
# Processing quantile index 4992: 491.980076 341.168482
# Processing quantile index 5056: 497.133683 2717.590694
# Processing quantile index 5120: 497.122098 496.208602
# Processing quantile index 5184: 493.929745 326.299044
# Processing quantile index 5248: 499.192824 3646.329104
# Processing quantile index 5312: 499.432971 519.943627
# Processing quantile index 5376: 475.469695 95.429467
# Processing quantile index 5440: 477.509773 746.593508
# Processing quantile index 5504: 477.572026 482.923525
# Processing quantile index 5568: 482.181250 2836.654542
# Processing quantile index 5632: 484.197210 761.005211
# Processing quantile index 5696: 484.231126 487.234395
# Processing quantile index 5760: 486.095944 739.587374
# Processing quantile index 5824: 483.387764 321.954616
# Processing quantile index 5888: 484.981117 692.786720
# Processing quantile index 5952: 485.446311 532.431498
# Processing quantile index 6016: 487.209973 735.828687
# Processing quantile index 6080: 486.607233 435.914790
# Processing quantile index 6144: 488.050831 679.578272
# Processing quantile index 6208: 485.798323 336.642194
# Processing quantile index 6272: 487.423463 721.567713
# Processing quantile index 6336: 487.537746 499.003530
# Processing quantile index 6400: 489.208627 740.429900
# Processing quantile index 6464: 489.134839 481.866783
# Processing quantile index 6528: 490.733153 732.471590
# Processing quantile index 6592: 482.412599 176.743785
# Processing quantile index 6656: 484.033457 740.191023
# Processing quantile index 6720: 487.723422 2354.222008
# Processing quantile index 6784: 487.541734 469.189402
# Processing quantile index 6848: 488.948369 704.360887
# Processing quantile index 6912: 489.080023 503.588733
# Processing quantile index 6976: 490.635444 747.318905
# Processing quantile index 7040: 488.756941 344.843455
# Processing quantile index 7104: 490.250945 738.598378
# Processing quantile index 7168: 490.163303 480.626121
# Processing quantile index 7232: 491.470972 700.895994
# Processing quantile index 7296: 491.276465 470.246402
# Processing quantile index 7360: 492.833512 771.632333
# Processing quantile index 7424: 490.650169 325.047717
# Processing quantile index 7488: 492.056554 737.162344
# Processing quantile index 7552: 491.884765 472.580994
# Processing quantile index 7616: 493.287403 743.444363
# Processing quantile index 7680: 493.219884 485.314936
# Processing quantile index 7744: 494.540351 728.624471
# Processing quantile index 7808: 489.713354 224.533161
# Processing quantile index 7872: 493.004259 2736.596181
# Processing quantile index 7936: 494.330613 738.813859
# Processing quantile index 8000: 494.211762 479.904346
# Processing quantile index 8064: 495.664933 783.718833
# Processing quantile index 8128: 495.548136 481.259457
# Processing quantile index 8192: 496.836933 741.874605
# Processing quantile index 8256: 495.028063 337.668253
# Processing quantile index 8320: 496.234103 723.672492
# Processing quantile index 8384: 493.899048 306.441914
# Processing quantile index 8448: 494.981353 694.288283
# Processing quantile index 8512: 494.781111 469.699226
# Processing quantile index 8576: 495.868487 700.669139
# Processing quantile index 8640: 493.520583 301.943313
# Processing quantile index 8704: 494.578936 696.106715
# Processing quantile index 8768: 494.203463 447.953115
# Processing quantile index 8832: 494.648894 564.332458
# Processing quantile index 8896: 494.078948 426.295083
# Processing quantile index 8960: 494.864456 635.246447
# Processing quantile index 9024: 497.802673 2949.742932
# Processing quantile index 9088: 488.009766 129.315569
# Processing quantile index 9152: 488.685329 608.251680
# Processing quantile index 9216: 488.000083 406.491275
# Processing quantile index 9280: 488.944093 677.733820
# Processing quantile index 9344: 488.457799 426.893703
# Processing quantile index 9408: 489.306517 655.627309
# Processing quantile index 9472: 486.834180 279.347902
# Processing quantile index 9536: 487.848253 705.271381
# Processing quantile index 9600: 487.621764 456.073016
# Processing quantile index 9664: 488.650446 714.859486
# Processing quantile index 9728: 487.539981 362.982631
# Processing quantile index 9792: 487.706993 514.496489
# Processing quantile index 9856: 483.195984 200.067716
# Processing quantile index 9920: 484.072714 671.785618
# Processing quantile index 9984: 483.824080 448.146059
# Processing quantile index 10048: 484.803621 708.605773
# Processing quantile index 10112: 484.844235 491.306193
# Processing quantile index 10176: 487.449577 3228.638426
# Processing quantile index 10240: 488.218360 651.624613
# Processing quantile index 10304: 483.278453 184.533702
# Processing quantile index 10368: 484.147635 681.476039
# Processing quantile index 10432: 483.555955 403.642309
# Processing quantile index 10496: 484.495879 709.193613
# Processing quantile index 10560: 484.219205 442.753842
# Processing quantile index 10624: 485.094550 691.291638
# Processing quantile index 10688: 483.356458 303.087101
# Processing quantile index 10752: 483.991556 620.046419
# Processing quantile index 10816: 483.702180 439.550840
# Processing quantile index 10880: 484.444942 654.224371
# Processing quantile index 10944: 484.060408 426.507763
# Processing quantile index 11008: 484.899492 689.184913
# Processing quantile index 11072: 482.888128 281.821113
# Processing quantile index 11136: 483.729261 692.372160
# Processing quantile index 11200: 483.441086 438.035263
# Processing quantile index 11264: 484.309699 706.431403
# Processing quantile index 11328: 486.630916 3110.239679
# Processing quantile index 11392: 486.182809 418.046275
# Processing quantile index 11456: 487.049054 713.256356
# Processing quantile index 11520: 483.041763 195.345409
# Processing quantile index 11584: 483.808063 677.178165
# Processing quantile index 11648: 483.437184 424.532753
# Processing quantile index 11712: 484.192780 676.681412
# Processing quantile index 11776: 484.031654 456.247429
# Processing quantile index 11840: 484.570240 609.321699
# Processing quantile index 11904: 483.031079 304.247864
# Processing quantile index 11968: 483.827258 697.744213
# Processing quantile index 12032: 483.824135 483.240843
# Processing quantile index 12096: 484.531127 668.057330
# Processing quantile index 12160: 484.291032 442.819577
# Processing quantile index 12224: 485.143546 728.950944
# Processing quantile index 12288: 483.926686 327.181958
# Processing quantile index 12352: 484.736864 714.362962
# Processing quantile index 12416: 484.711692 479.901773
# Processing quantile index 12480: 486.569741 1898.156938
# Processing quantile index 12544: 487.012126 591.962493
# Processing quantile index 12608: 486.818793 451.675059
# Processing quantile index 12672: 487.527983 683.756947
# Processing quantile index 12736: 473.440631 70.438806
# Processing quantile index 12800: 472.941961 390.989005
# Processing quantile index 12864: 474.036289 882.378610
# Processing quantile index 12928: 474.021442 471.055921
# Processing quantile index 12992: 473.849239 441.454133
# Processing quantile index 13056: 473.618301 430.979298
# Processing quantile index 13120: 474.821289 985.431403
# Processing quantile index 13184: 474.654060 442.691778
# Processing quantile index 13248: 474.478218 440.835730
# Processing quantile index 13312: 475.651167 974.138147
# Processing quantile index 13376: 474.672527 332.414225
# Processing quantile index 13440: 475.263693 642.502115
# Processing quantile index 13504: 473.239964 249.835689
# Processing quantile index 13568: 474.379603 964.426059
# Processing quantile index 13632: 474.933698 631.245972
# Processing quantile index 13696: 474.390649 381.481351
# Processing quantile index 13760: 475.536940 984.748163
# Processing quantile index 13824: 474.719649 346.633561
# Processing quantile index 13888: 475.304606 647.693935
# Processing quantile index 13952: 476.440579 989.755160
# Processing quantile index 14016: 476.232552 434.842157
# Processing quantile index 14080: 476.177351 464.389067
# Processing quantile index 14144: 476.051197 449.832769
# Processing quantile index 14208: 477.166617 989.598263
# Processing quantile index 14272: 476.936850 430.876915
# Processing quantile index 14336: 475.733326 304.424868
# Processing quantile index 14400: 476.799999 957.900947
# Processing quantile index 14464: 476.552764 426.762717
# Processing quantile index 14528: 477.162358 671.202744
# Processing quantile index 14592: 476.328198 341.005523
# Processing quantile index 14656: 477.416019 996.064713
# Processing quantile index 14720: 477.952025 643.362915
# Processing quantile index 14784: 477.830922 451.517794
# Processing quantile index 14848: 478.890794 982.096506
# Processing quantile index 14912: 478.089537 344.402348
# Processing quantile index 14976: 478.644241 655.981389
# Processing quantile index 15040: 479.665692 958.119763
# Processing quantile index 15104: 479.513662 446.273767
# Processing quantile index 15168: 476.289325 184.115393
# Processing quantile index 15232: 476.149634 445.203509
# Processing quantile index 15296: 477.183434 987.421442
# Processing quantile index 15360: 477.713340 650.309622
# Processing quantile index 15424: 476.869002 334.835306
# Processing quantile index 15488: 477.904267 1002.320476
# Processing quantile index 15552: 477.765269 446.348715
# Processing quantile index 15616: 478.301795 657.809118
# Processing quantile index 15680: 475.887230 213.233892
# Processing quantile index 15744: 475.802439 455.901060
# Processing quantile index 15808: 475.514045 413.812252
# Processing quantile index 15872: 475.420005 453.278245
# Processing quantile index 15936: 476.402430 977.187847
# Processing quantile index 16000: 474.637270 246.873750
# Processing quantile index 16064: 475.149844 650.874117
# Processing quantile index 16128: 476.099293 955.160552
# Processing quantile index 16192: 475.975415 446.686662
# Processing quantile index 16256: 475.940121 467.175763
# Processing quantile index 16320: 475.887950 462.996968
# Processing quantile index 16384: 476.856019 990.829234
# Processing quantile index 16448: 477.391438 669.966446
# Processing quantile index 16512: 475.219748 219.084843
# Processing quantile index 16576: 476.154180 966.436452
# Processing quantile index 16640: 476.107196 464.242896
# Processing quantile index 16704: 476.590244 647.356549
# Processing quantile index 16768: 477.535465 989.999727
# Processing quantile index 16832: 475.747727 240.174377
# Processing quantile index 16896: 476.261652 665.267549
# Processing quantile index 16960: 476.139368 445.913480
# Processing quantile index 17024: 477.033829 949.928184
# Processing quantile index 17088: 476.379650 349.052658
# Processing quantile index 17152: 476.913781 680.691495
# Processing quantile index 17216: 477.834040 989.583670
# Processing quantile index 17280: 477.671917 437.721695
# Processing quantile index 17344: 477.542398 444.966617
# Processing quantile index 17408: 476.054228 258.091162
# Processing quantile index 17472: 476.876796 899.742434
# Processing quantile index 17536: 477.448678 709.842491
# Processing quantile index 17600: 472.809578 129.101686
# Processing quantile index 17664: 473.719942 1006.831809
# Processing quantile index 17728: 473.608404 444.709347
# Processing quantile index 17792: 474.089684 659.820554
# Processing quantile index 17856: 474.921495 927.151720
# Processing quantile index 17920: 474.156558 327.145673
# Processing quantile index 17984: 473.814436 394.178349
# Processing quantile index 18048: 473.708090 445.604069
# Processing quantile index 18112: 474.517484 915.765030
# Processing quantile index 18176: 473.791370 330.617296
# Processing quantile index 18240: 474.240240 648.810122
# Processing quantile index 18304: 475.089103 969.833828
# Processing quantile index 18368: 474.924047 431.999562
# Processing quantile index 18432: 474.004853 304.733134
# Processing quantile index 18496: 473.797500 420.784801
# Processing quantile index 18560: 474.235942 647.362794
# Processing quantile index 18624: 474.521258 574.810719
# Processing quantile index 18688: 473.675533 311.907574
# Processing quantile index 18752: 474.505822 972.021697
# Processing quantile index 18816: 474.415910 449.462200
# Processing quantile index 18880: 474.878863 665.932656
# Processing quantile index 18944: 475.694258 963.982748
# Processing quantile index 19008: 475.111931 348.743838
# Processing quantile index 19072: 475.527470 642.396022
# Processing quantile index 19136: 475.433336 448.949533
# Processing quantile index 19200: 476.255195 985.764329
# Processing quantile index 19264: 475.377313 306.104351
# Processing quantile index 19328: 475.286183 449.357617
# Processing quantile index 19392: 476.105206 992.738346
# Processing quantile index 19456: 475.922032 426.234163
# Processing quantile index 19520: 475.741653 426.590454
# Processing quantile index 19584: 475.661913 452.527864
# Processing quantile index 19648: 476.437690 951.102822
# Processing quantile index 19712: 476.841780 644.713414
# Processing quantile index 19776: 476.202646 337.056439
# Processing quantile index 19840: 476.960566 938.533005
# Processing quantile index 19904: 475.437076 238.890229
# Processing quantile index 19968: 474.577802 303.811236
# Processing quantile index 20032: 475.074776 705.616205
# Processing quantile index 20096: 469.012488 93.913323
# Processing quantile index 20160: 469.447281 662.210059
# Processing quantile index 20224: 469.378671 448.720640
# Processing quantile index 20288: 470.118223 936.284085
# Processing quantile index 20352: 470.071447 455.698287
# Processing quantile index 20416: 470.010854 451.503365
# Processing quantile index 20480: 470.736069 927.026847
# Processing quantile index 20544: 470.665396 449.089987
# Processing quantile index 20608: 470.666126 470.900568
# Processing quantile index 20672: 470.580103 444.425148
# Processing quantile index 20736: 471.298173 929.350496
# Processing quantile index 20800: 471.257193 458.344570
# Processing quantile index 20864: 468.885510 177.903427
# Processing quantile index 20928: 468.967739 497.404824
# Processing quantile index 20992: 468.736518 403.656877
# Processing quantile index 21056: 469.150630 660.567452
# Processing quantile index 21120: 469.871063 949.649256
# Processing quantile index 21184: 469.297262 334.497343
# Processing quantile index 21248: 469.676121 640.944997
# Processing quantile index 21312: 469.583547 440.742359
# Processing quantile index 21376: 470.314058 975.823764
# Processing quantile index 21440: 470.258914 452.537018
# Processing quantile index 21504: 470.159987 439.207790
# Processing quantile index 21568: 470.881135 971.627645
# Processing quantile index 21632: 470.760983 433.485490
# Processing quantile index 21696: 469.913675 292.170194
# Processing quantile index 21760: 470.577525 903.059892
# Processing quantile index 21824: 470.470062 436.572700
# Processing quantile index 21888: 470.825557 634.249825
# Processing quantile index 21952: 470.291447 338.834402
# Processing quantile index 22016: 470.992299 963.481052
# Processing quantile index 22080: 470.900829 441.411304
# Processing quantile index 22144: 471.289719 659.068871
# Processing quantile index 22208: 471.987933 968.374889
# Processing quantile index 22272: 471.384241 326.482393
# Processing quantile index 22336: 471.733012 635.314103
# Processing quantile index 22400: 471.631304 438.626477
# Processing quantile index 22464: 472.318866 964.394875
# Processing quantile index 22528: 470.561545 204.064991
# Processing quantile index 22592: 470.528780 459.272269
# Processing quantile index 22656: 471.198785 947.420371
# Processing quantile index 22720: 471.098029 437.947362
# Processing quantile index 22784: 471.044820 452.885933
# Processing quantile index 22848: 471.708001 945.704749
# Processing quantile index 22912: 471.599210 435.723745
# Processing quantile index 22976: 471.945635 640.341063
# Processing quantile index 23040: 471.426017 337.876087
# Processing quantile index 23104: 472.112752 992.705305
# Processing quantile index 23168: 472.009137 437.357977
# Processing quantile index 23232: 472.336010 630.361015
# Processing quantile index 23296: 472.959951 908.684700
# Processing quantile index 23360: 471.817451 251.061263
# Processing quantile index 23424: 472.160652 642.834458
# Processing quantile index 23488: 472.051526 435.234866
# Processing quantile index 23552: 472.692627 942.424407
# Processing quantile index 23616: 472.642307 454.824255
# Processing quantile index 23680: 472.575476 449.141083
# Processing quantile index 23744: 473.222317 958.793937
# Processing quantile index 23808: 473.184237 459.467225
# Processing quantile index 23872: 472.909626 388.941630
# Processing quantile index 23936: 473.555152 964.762277
# Processing quantile index 24000: 473.478297 446.383600
# Processing quantile index 24064: 473.857939 677.598669
# Processing quantile index 24128: 472.792203 256.166123
# Processing quantile index 24192: 472.710871 443.920965
# Processing quantile index 24256: 472.519312 409.753808
# Processing quantile index 24320: 472.432473 441.669131
# Processing quantile index 24384: 472.982926 848.788979
# Processing quantile index 24448: 472.354405 313.588060
# Processing quantile index 24512: 472.742118 688.675696
# Processing quantile index 24576: 472.294617 346.625504
# Processing quantile index 24640: 472.407994 520.377041
# Processing quantile index 24704: 471.421619 261.339055
# Processing quantile index 24768: 470.812137 314.074942
# Processing quantile index 24832: 471.421548 944.593256
# Processing quantile index 24896: 471.354798 446.807853
# Processing quantile index 24960: 469.740413 201.404737
# Processing quantile index 25024: 470.342540 940.522461
# Processing quantile index 25088: 470.270541 443.712570
# Processing quantile index 25152: 470.578372 633.005450
# Processing quantile index 25216: 470.107126 337.343203
# Processing quantile index 25280: 470.723322 973.449290
# Processing quantile index 25344: 471.034981 637.847232
# Processing quantile index 25408: 470.952000 440.239994
# Processing quantile index 25472: 471.522102 907.787395
# Processing quantile index 25536: 471.031598 333.114665
# Processing quantile index 25600: 471.395902 681.792787
# Processing quantile index 25664: 471.988209 948.907366
# Processing quantile index 25728: 471.832951 416.847897
# Processing quantile index 25792: 471.150823 297.975892
# Processing quantile index 25856: 471.046216 432.360687
# Processing quantile index 25920: 471.656922 990.419788
# Processing quantile index 25984: 471.631977 461.741823
# Processing quantile index 26048: 471.586791 453.929772
# Processing quantile index 26112: 472.163475 940.008670
# Processing quantile index 26176: 472.083463 441.555069
# Processing quantile index 26240: 472.394608 646.732687
# Processing quantile index 26304: 471.970255 344.930748
# Processing quantile index 26368: 472.539889 937.667514
# Processing quantile index 26432: 472.772180 592.841034
# Processing quantile index 26496: 472.081218 294.387479
# Processing quantile index 26560: 472.622833 900.198044
# Processing quantile index 26624: 471.510112 238.491003
# Processing quantile index 26688: 471.778871 618.416556
# Processing quantile index 26752: 472.158573 710.669371
# Processing quantile index 26816: 471.981586 408.046539
# Processing quantile index 26880: 471.881553 433.394506
# Processing quantile index 26944: 471.772710 430.105759
# Processing quantile index 27008: 472.315907 916.650012
# Processing quantile index 27072: 472.240955 442.601268
# Processing quantile index 27136: 472.166230 442.545083
# Processing quantile index 27200: 472.719440 939.383658
# Processing quantile index 27264: 472.615793 432.329352
# Processing quantile index 27328: 472.918244 650.166289
# Processing quantile index 27392: 466.536418 68.992018
# Processing quantile index 27456: 466.797189 613.586391
# Processing quantile index 27520: 467.086060 635.907081
# Processing quantile index 27584: 467.167395 504.978490
# Processing quantile index 27648: 467.468734 647.472095
# Processing quantile index 27712: 467.770126 648.352537
# Processing quantile index 27776: 467.816172 488.643730
# Processing quantile index 27840: 468.102385 637.327793
# Processing quantile index 27904: 468.391876 640.772110
# Processing quantile index 27968: 467.870772 315.050298
# Processing quantile index 28032: 468.163764 644.552417
# Processing quantile index 28096: 467.960915 393.317210
# Processing quantile index 28160: 468.039695 505.390159
# Processing quantile index 28224: 467.795055 380.326318
# Processing quantile index 28288: 468.070506 632.248061
# Processing quantile index 28352: 467.814712 376.800171
# Processing quantile index 28416: 467.899766 508.886240
# Processing quantile index 28480: 468.053759 548.154116
# Processing quantile index 28544: 467.762461 366.312260
# Processing quantile index 28608: 467.309404 326.338316
# Processing quantile index 28672: 467.371191 496.728310
# Processing quantile index 28736: 467.657939 644.924070
# Processing quantile index 28800: 467.945831 646.696852
# Processing quantile index 28864: 468.014834 501.278158
# Processing quantile index 28928: 468.275981 625.747012
# Processing quantile index 28992: 468.540452 629.148058
# Processing quantile index 29056: 467.710621 259.506612
# Processing quantile index 29120: 467.942855 604.129902
# Processing quantile index 29184: 467.963432 477.517408
# Processing quantile index 29248: 467.997477 484.055605
# Processing quantile index 29312: 468.242029 615.141519
# Processing quantile index 29376: 468.503688 629.654243
# Processing quantile index 29440: 468.460556 449.467468
# Processing quantile index 29504: 468.720302 629.201147
# Processing quantile index 29568: 468.978298 628.444001
# Processing quantile index 29632: 468.639944 351.483665
# Processing quantile index 29696: 468.591690 447.268682
# Processing quantile index 29760: 468.835249 617.841514
# Processing quantile index 29824: 468.475437 345.262155
# Processing quantile index 29888: 468.761760 655.436809
# Processing quantile index 29952: 468.710322 445.862376
# Processing quantile index 30016: 468.738489 482.303135
# Processing quantile index 30080: 468.865699 537.246985
# Processing quantile index 30144: 468.486674 339.497342
# Processing quantile index 30208: 468.673791 577.270619
# Processing quantile index 30272: 468.915468 619.760108
# Processing quantile index 30336: 468.944423 483.053010
# Processing quantile index 30400: 468.991737 492.547544
# Processing quantile index 30464: 469.095964 524.459064
# Processing quantile index 30528: 469.148828 495.741244
# Processing quantile index 30592: 469.155058 472.145438
# Processing quantile index 30656: 469.102399 445.216062
# Processing quantile index 30720: 468.376264 268.956694
# Processing quantile index 30784: 468.091084 362.227345
# Processing quantile index 30848: 468.319028 611.566410
# Processing quantile index 30912: 468.361359 489.696490
# Processing quantile index 30976: 468.597420 619.378295
# Processing quantile index 31040: 468.267720 349.313380
# Processing quantile index 31104: 468.494749 612.525114
# Processing quantile index 31168: 468.754681 641.816972
# Processing quantile index 31232: 468.510675 373.760905
# Processing quantile index 31296: 468.809578 680.753640
# Processing quantile index 31360: 469.066177 640.493850
# Processing quantile index 31424: 469.154774 517.004497
# Processing quantile index 31488: 469.408478 639.100083
# Processing quantile index 31552: 469.664153 641.600673
# Processing quantile index 31616: 469.548530 418.728376
# Processing quantile index 31680: 469.771279 613.556940
# Processing quantile index 31744: 470.015296 632.695118
# Processing quantile index 31808: 469.795824 381.449909
# Processing quantile index 31872: 470.050107 643.030025
# Processing quantile index 31936: 470.324894 663.481821
# Processing quantile index 32000: 470.393290 507.198770
# Processing quantile index 32064: 470.628303 627.341014
# Processing quantile index 32128: 470.881656 644.781553
# Processing quantile index 32192: 470.890342 475.291230
# Processing quantile index 32256: 470.785850 423.514670
# Processing quantile index 32320: 468.700470 144.996084
# Processing quantile index 32384: 469.016466 711.136280
# Processing quantile index 32448: 469.344371 726.270687
# Processing quantile index 32512: 469.420070 511.223835
# Processing quantile index 32576: 469.538097 538.293082
# Processing quantile index 32640: 469.549182 475.260094
# Processing quantile index 32704: 469.585764 489.015824
# Processing quantile index 32768: 469.801161 613.632678
# Processing quantile index 32832: 470.026217 622.775290
# Processing quantile index 32896: 469.535326 305.732358
# Processing quantile index 32960: 469.692930 567.624825
# Processing quantile index 33024: 469.629064 438.894694
# Processing quantile index 33088: 469.395182 373.432294
# Processing quantile index 33152: 469.710064 719.108937
# Processing quantile index 33216: 469.989542 679.382198
# Processing quantile index 33280: 470.101512 536.428895
# Processing quantile index 33344: 470.399735 701.960879
# Processing quantile index 33408: 470.687658 691.063840
# Processing quantile index 33472: 470.253410 317.398264
# Processing quantile index 33536: 470.444000 596.986232
# Processing quantile index 33600: 470.588164 560.608184
# Processing quantile index 33664: 470.911053 736.054665
# Processing quantile index 33728: 471.223753 724.158603
# Processing quantile index 33792: 471.383693 574.068238
# Processing quantile index 33856: 471.693659 722.564107
# Processing quantile index 33920: 471.962476 675.656075
# Processing quantile index 33984: 470.847256 209.046252
# Processing quantile index 34048: 471.081580 640.283023
# Processing quantile index 34112: 470.759231 345.122771
# Processing quantile index 34176: 470.625584 408.771678
# Processing quantile index 34240: 470.862916 644.391500
# Processing quantile index 34304: 471.114208 659.381325
# Processing quantile index 34368: 471.251138 558.214814
# Processing quantile index 34432: 471.488941 646.745152
# Processing quantile index 34496: 471.725421 646.057156
# Processing quantile index 34560: 471.385030 339.385742
# Processing quantile index 34624: 471.583928 610.741293
# Processing quantile index 34688: 470.727102 237.387330
# Processing quantile index 34752: 470.959450 642.973037
# Processing quantile index 34816: 471.195697 647.589245
# Processing quantile index 34880: 470.782752 318.796732
# Processing quantile index 34944: 471.091470 733.085697
# Processing quantile index 35008: 471.394022 725.960353
# Processing quantile index 35072: 471.301056 425.409396
# Processing quantile index 35136: 471.616838 745.252436
# Processing quantile index 35200: 471.924715 735.536334
# Processing quantile index 35264: 472.024131 533.881177
# Processing quantile index 35328: 472.107084 522.723912
# Processing quantile index 35392: 472.411242 733.135751
# Processing quantile index 35456: 472.508283 533.061653
# Processing quantile index 35520: 472.808835 730.079025
# Processing quantile index 35584: 473.101425 720.589538
# Processing quantile index 35648: 472.547075 286.134598
# Processing quantile index 35712: 472.750088 621.463246
# Processing quantile index 35776: 473.059844 745.697543
# Processing quantile index 35840: 473.198631 566.026961
# Processing quantile index 35904: 473.228779 490.737647
# Processing quantile index 35968: 473.354243 556.059410
# Processing quantile index 36032: 473.629846 703.984055
# Processing quantile index 36096: 473.926623 732.245810
# Processing quantile index 36160: 473.370026 284.753845
# Processing quantile index 36224: 473.460854 531.029587
# Processing quantile index 36288: 473.692403 655.000198
# Processing quantile index 36352: 473.790594 536.893462
# Processing quantile index 36416: 473.678042 417.362499
# Processing quantile index 36480: 473.946044 698.966936
# Processing quantile index 36544: 473.894574 446.270057
# Processing quantile index 36608: 474.192430 739.642395
# Processing quantile index 36672: 474.480427 727.061467
# Processing quantile index 36736: 474.332411 402.403090
# Processing quantile index 36800: 474.608100 712.215526
# Processing quantile index 36864: 474.884322 713.736160
# Processing quantile index 36928: 475.006761 557.852874
# Processing quantile index 36992: 475.281395 713.210874
# Processing quantile index 37056: 475.541728 695.843264
# Processing quantile index 37120: 475.004795 287.229454
# Processing quantile index 37184: 475.283899 720.997918
# Processing quantile index 37248: 473.621599 156.205531
# Processing quantile index 37312: 473.540036 430.402296
# Processing quantile index 37376: 473.316082 371.018308
# Processing quantile index 37440: 473.227975 426.827182
# Processing quantile index 37504: 473.426581 627.483260
# Processing quantile index 37568: 473.494324 516.831295
# Processing quantile index 37632: 473.429286 438.105324
# Processing quantile index 37696: 473.612142 612.778199
# Processing quantile index 37760: 473.548396 438.764847
# Processing quantile index 37824: 473.350588 379.758673
# Processing quantile index 37888: 473.525011 605.356053
# Processing quantile index 37952: 473.734265 641.576138
# Processing quantile index 38016: 473.791807 510.567496
# Processing quantile index 38080: 473.957215 597.958336
# Processing quantile index 38144: 474.147639 623.104890
# Processing quantile index 38208: 474.168891 487.183107
# Processing quantile index 38272: 474.344951 609.437902
# Processing quantile index 38336: 473.759801 272.637620
# Processing quantile index 38400: 473.961380 636.075845
# Processing quantile index 38464: 473.588767 321.797146
# Processing quantile index 38528: 473.427053 392.813596
# Processing quantile index 38592: 473.703440 730.400840
# Processing quantile index 38656: 473.977840 728.408962
# Processing quantile index 38720: 474.104506 565.361752
# Processing quantile index 38784: 474.380892 732.853536
# Processing quantile index 38848: 474.657558 734.114177
# Processing quantile index 38912: 473.882771 238.035048
# Processing quantile index 38976: 473.967265 531.596412
# Processing quantile index 39040: 474.223320 706.745729
# Processing quantile index 39104: 474.354365 570.525043
# Processing quantile index 39168: 474.615919 715.751536
# Processing quantile index 39232: 474.878935 718.587258
# Processing quantile index 39296: 474.911932 496.040802
# Processing quantile index 39360: 475.145653 680.891779
# Processing quantile index 39424: 475.412015 725.556139
# Processing quantile index 39488: 475.291048 410.889044
# Processing quantile index 39552: 475.567328 741.513925
# Processing quantile index 39616: 475.460122 417.320973
# Processing quantile index 39680: 475.703135 695.857695
# Processing quantile index 39744: 475.960964 716.848675
# Processing quantile index 39808: 476.084815 567.843360
# Processing quantile index 39872: 476.344503 720.947572
# Processing quantile index 39936: 476.616322 739.520136
# Processing quantile index 40000: 476.523882 425.078632
# Processing quantile index 40064: 476.792490 736.133386
# Processing quantile index 40128: 477.051117 722.324955
# Processing quantile index 40192: 477.032247 465.487477
# Processing quantile index 40256: 477.300850 738.409428
# Processing quantile index 40320: 477.486455 632.093229
# Processing quantile index 40384: 477.617188 577.173804
# Processing quantile index 40448: 477.886502 741.831551
# Processing quantile index 40512: 478.150092 734.029866
# Processing quantile index 40576: 477.706175 300.882977
# Processing quantile index 40640: 477.973799 741.255926
# Processing quantile index 40704: 478.237871 736.686927
# Processing quantile index 40768: 478.335762 549.927286
# Processing quantile index 40832: 478.344648 484.073063
# Processing quantile index 40896: 478.466664 571.467558
# Processing quantile index 40960: 478.729643 737.883719
# Processing quantile index 41024: 478.980786 721.081200
# Processing quantile index 41088: 478.869505 416.798707
# Processing quantile index 41152: 479.128728 734.329059
# Processing quantile index 41216: 479.386832 733.434215
# Processing quantile index 41280: 479.511833 576.284137
# Processing quantile index 41344: 479.745491 699.640989
# Processing quantile index 41408: 479.858181 565.698929
# Processing quantile index 41472: 479.975114 569.812938
# Processing quantile index 41536: 480.236005 741.358285
# Processing quantile index 41600: 480.411277 629.524298
# Processing quantile index 41664: 480.314979 424.947413
# Processing quantile index 41728: 480.570388 735.010681
# Processing quantile index 41792: 480.835375 750.734011
# Processing quantile index 41856: 480.956314 575.472453
# Processing quantile index 41920: 481.210936 736.058701
# Processing quantile index 41984: 481.467755 740.229805
# Processing quantile index 42048: 481.354945 417.225623
# Processing quantile index 42112: 481.585081 702.133471
# Processing quantile index 42176: 479.787646 138.832521
# Processing quantile index 42240: 480.026366 714.205208
# Processing quantile index 42304: 480.281745 740.178778
# Processing quantile index 42368: 480.401796 575.484790
# Processing quantile index 42432: 480.658324 743.477308
# Processing quantile index 42496: 480.908854 734.851724
# Processing quantile index 42560: 481.028122 575.857625
# Processing quantile index 42624: 481.125033 555.556499
# Processing quantile index 42688: 481.383089 748.901364
# Processing quantile index 42752: 481.293910 428.363109
# Processing quantile index 42816: 481.549544 746.358939
# Processing quantile index 42880: 481.806780 749.740128
# Processing quantile index 42944: 481.845891 509.559540
# Processing quantile index 43008: 482.102063 749.461726
# Processing quantile index 43072: 482.352201 740.560633
# Processing quantile index 43136: 482.460369 568.215978
# Processing quantile index 43200: 482.707157 736.692993
# Processing quantile index 43264: 482.387044 333.224246
# Processing quantile index 43328: 482.635686 740.736378
# Processing quantile index 43392: 482.883126 739.583298
# Processing quantile index 43456: 483.001700 579.476330
# Processing quantile index 43520: 483.234667 718.568022
# Processing quantile index 43584: 483.472545 726.740620
# Processing quantile index 43648: 483.577958 567.899823
# Processing quantile index 43712: 483.827377 746.371390
# Processing quantile index 43776: 483.847681 498.125699
# Processing quantile index 43840: 483.229358 257.845484
# Processing quantile index 43904: 483.440311 689.678936
# Processing quantile index 43968: 483.681753 735.756081
# Processing quantile index 44032: 483.792604 574.198402
# Processing quantile index 44096: 484.029776 730.371031
# Processing quantile index 44160: 484.262237 723.752490
# Processing quantile index 44224: 484.367018 569.371793
# Processing quantile index 44288: 484.607094 737.038879
# Processing quantile index 44352: 484.846904 737.340530
# Processing quantile index 44416: 484.745390 423.322987
# Processing quantile index 44480: 484.434619 335.266468
# Processing quantile index 44544: 483.853523 263.870756
# Processing quantile index 44608: 483.979651 591.249292
# Processing quantile index 44672: 483.685671 339.816665
# Processing quantile index 44736: 483.705210 497.739619
# Processing quantile index 44800: 483.907561 683.887596
# Processing quantile index 44864: 484.121785 701.511437
# Processing quantile index 44928: 484.026354 425.262476
# Processing quantile index 44992: 484.216967 669.226517
# Processing quantile index 45056: 484.368418 620.889707
# Processing quantile index 45120: 484.324562 455.302550
# Processing quantile index 45184: 484.562765 741.757756
# Processing quantile index 45248: 484.796712 735.496027
# Processing quantile index 45312: 484.903774 574.621228
# Processing quantile index 45376: 485.142616 744.915337
# Processing quantile index 45440: 485.360483 712.087052
# Processing quantile index 45504: 484.900091 289.756304
# Processing quantile index 45568: 484.760648 402.470664
# Processing quantile index 45632: 484.939536 657.762374
# Processing quantile index 45696: 483.988794 201.841793
# Processing quantile index 45760: 484.013562 502.369200
# Processing quantile index 45824: 483.996051 471.791933
# Processing quantile index 45888: 484.219612 723.498900
# Processing quantile index 45952: 484.416604 683.906762
# Processing quantile index 46016: 484.301221 413.572533
# Processing quantile index 46080: 484.519488 716.789336
# Processing quantile index 46144: 484.732474 709.189866
# Processing quantile index 46208: 484.803911 542.441789
# Processing quantile index 46272: 485.009561 699.130775
# Processing quantile index 46336: 485.094001 554.946634
# Processing quantile index 46400: 485.175224 552.104582
# Processing quantile index 46464: 485.368575 682.585079
# Processing quantile index 46528: 485.584260 716.850590
# Processing quantile index 46592: 485.468211 413.606306
# Processing quantile index 46656: 485.683029 716.492788
# Processing quantile index 46720: 485.844613 641.407508
# Processing quantile index 46784: 485.555596 338.541256
# Processing quantile index 46848: 485.521987 462.138496
# Processing quantile index 46912: 485.318819 371.519480
# Processing quantile index 46976: 485.521295 699.405834
# Processing quantile index 47040: 485.503216 472.586818
# Processing quantile index 47104: 484.612864 206.402917
# Processing quantile index 47168: 484.837783 736.379751
# Processing quantile index 47232: 484.748874 427.034958
# Processing quantile index 47296: 484.777066 506.517353
# Processing quantile index 47360: 484.991949 721.251695
# Processing quantile index 47424: 485.161407 654.350358
# Processing quantile index 47488: 485.201414 516.778562
# Processing quantile index 47552: 485.292725 564.056163
# Processing quantile index 47616: 485.477669 677.243087
# Processing quantile index 47680: 485.358357 410.330676
# Processing quantile index 47744: 485.583230 741.538506
# Processing quantile index 47808: 485.803278 733.907448
# Processing quantile index 47872: 485.900498 571.305798
# Processing quantile index 47936: 486.121310 736.458541
# Processing quantile index 48000: 486.339907 733.330026
# Processing quantile index 48064: 486.425769 560.664387
# Processing quantile index 48128: 486.233213 374.806731
# Processing quantile index 48192: 486.048357 377.984409
# Processing quantile index 48256: 486.206069 643.412262
# Processing quantile index 48320: 486.407776 707.815412
# Processing quantile index 48384: 486.312641 423.739299
# Processing quantile index 48448: 486.420223 584.107702
# Processing quantile index 48512: 486.537329 594.969704
# Processing quantile index 48576: 486.564022 507.676469
# Processing quantile index 48640: 486.390312 382.691425
# Processing quantile index 48704: 486.453047 539.319422
# Processing quantile index 48768: 485.923096 265.670096
# Processing quantile index 48832: 486.080996 646.049381
# Processing quantile index 48896: 486.230148 634.867842
# Processing quantile index 48960: 485.729956 271.974662
# Processing quantile index 49024: 485.838124 585.601124
# Processing quantile index 49088: 485.900573 538.967496
# Processing quantile index 49152: 485.976332 551.986511
# Processing quantile index 49216: 486.196908 746.367240
# Processing quantile index 49280: 486.407651 729.600800
# Processing quantile index 49344: 486.036584 306.181862
# Processing quantile index 49408: 486.259531 752.328873
# Processing quantile index 49472: 486.359659 578.287891
# Processing quantile index 49536: 486.574711 739.245199
# Processing quantile index 49600: 486.783738 729.265821
# Processing quantile index 49664: 486.879767 574.750413
# Processing quantile index 49728: 487.093689 739.090510
# Processing quantile index 49792: 487.303043 731.637097
# Processing quantile index 49856: 487.210776 424.655655
# Processing quantile index 49920: 487.423096 737.936459
# Processing quantile index 49984: 487.509852 566.102163
# Processing quantile index 50048: 487.600164 570.080374
# Processing quantile index 50112: 487.805185 726.774069
# Processing quantile index 50176: 487.641764 386.307546
# Processing quantile index 50240: 487.600564 457.309176
# Processing quantile index 50304: 487.757482 652.627441
# Processing quantile index 50368: 487.900194 633.615061
# Processing quantile index 50432: 487.381572 265.378298
# Processing quantile index 50496: 487.517670 625.057820
# Processing quantile index 50560: 487.662777 637.335359
# Processing quantile index 50624: 487.158065 268.019757
# Processing quantile index 50688: 487.356392 718.841265
# Processing quantile index 50752: 487.419569 543.187091
# Processing quantile index 50816: 487.608115 703.367954
# Processing quantile index 50880: 487.802084 713.006279
# Processing quantile index 50944: 487.390717 291.775767
# Processing quantile index 51008: 487.472632 562.760129
# Processing quantile index 51072: 487.664879 711.209761
# Processing quantile index 51136: 487.734194 550.132404
# Processing quantile index 51200: 487.798125 544.862962
# Processing quantile index 51264: 487.990559 713.013855
# Processing quantile index 51328: 488.061873 552.767397
# Processing quantile index 51392: 488.254808 714.907082
# Processing quantile index 51456: 488.437838 698.783164
# Processing quantile index 51520: 488.218969 358.912676
# Processing quantile index 51584: 488.085843 400.232975
# Processing quantile index 51648: 487.893977 370.504167
# Processing quantile index 51712: 487.834112 443.881325
# Processing quantile index 51776: 487.881875 529.793925
# Processing quantile index 51840: 487.749551 399.985481
# Processing quantile index 51904: 487.832879 566.182163
# Processing quantile index 51968: 487.929397 581.183856
# Processing quantile index 52032: 487.013021 192.875649
# Processing quantile index 52096: 487.049756 518.869262
# Processing quantile index 52160: 487.047511 485.227210
# Processing quantile index 52224: 487.133509 569.016956
# Processing quantile index 52288: 487.230116 581.300903
# Processing quantile index 52352: 487.331600 587.266609
# Processing quantile index 52416: 486.871569 274.731196
# Processing quantile index 52480: 486.903314 514.371283
# Processing quantile index 52544: 487.036155 627.396732
# Processing quantile index 52608: 486.801957 349.014536
# Processing quantile index 52672: 486.878829 559.505133
# Processing quantile index 52736: 486.897292 502.582709
# Processing quantile index 52800: 486.790152 412.073599
# Processing quantile index 52864: 486.823097 515.611230
# Processing quantile index 52928: 486.964075 640.069282
# Processing quantile index 52992: 486.947311 473.467046
# Processing quantile index 53056: 486.857847 422.574619
# Processing quantile index 53120: 486.646821 358.006068
# Processing quantile index 53184: 486.775129 623.139605
# Processing quantile index 53248: 486.900038 618.867088
# Processing quantile index 53312: 486.910239 495.548143
# Processing quantile index 53376: 487.005170 581.434368
# Processing quantile index 53440: 487.127978 616.859021
# Processing quantile index 53504: 487.133389 491.694062
# Processing quantile index 53568: 487.256308 617.521719
# Processing quantile index 53632: 487.257694 488.420568
# Processing quantile index 53696: 486.752213 260.387150
# Processing quantile index 53760: 486.845934 580.645799
# Processing quantile index 53824: 487.033228 719.563858
# Processing quantile index 53888: 486.879502 384.747791
# Processing quantile index 53952: 487.066312 719.517569
# Processing quantile index 54016: 486.939528 399.316099
# Processing quantile index 54080: 486.408624 253.311015
# Processing quantile index 54144: 486.506988 586.774948
# Processing quantile index 54208: 486.605028 586.614662
# Processing quantile index 54272: 486.242873 298.239084
# Processing quantile index 54336: 486.435598 732.705510
# Processing quantile index 54400: 486.420608 474.018856
# Processing quantile index 54464: 486.579974 674.386389
# Processing quantile index 54528: 486.674323 582.850850
# Processing quantile index 54592: 486.711228 520.328624
# Processing quantile index 54656: 486.902872 733.145763
# Processing quantile index 54720: 486.999016 585.780030
# Processing quantile index 54784: 486.884473 405.366097
# Processing quantile index 54848: 486.918212 517.622598
# Processing quantile index 54912: 487.012319 583.689842
# Processing quantile index 54976: 486.970935 453.879116
# Processing quantile index 55040: 487.148206 708.785391
# Processing quantile index 55104: 487.016327 395.043849
# Processing quantile index 55168: 486.970273 450.306661
# Processing quantile index 55232: 487.069992 591.474671
# Processing quantile index 55296: 487.146702 563.773034
# Processing quantile index 55360: 486.628283 253.522981
# Processing quantile index 55424: 486.696976 554.389624
# Processing quantile index 55488: 486.454660 339.901862
# Processing quantile index 55552: 486.527470 559.077469
# Processing quantile index 55616: 486.624587 588.609705
# Processing quantile index 55680: 486.641727 502.007495
# Processing quantile index 55744: 486.717078 562.488907
# Processing quantile index 55808: 486.804964 577.656959
# Processing quantile index 55872: 486.557000 336.910915
# Processing quantile index 55936: 486.640666 572.597564
# Processing quantile index 56000: 486.746294 600.702792
# Processing quantile index 56064: 486.622765 398.198340
# Processing quantile index 56128: 486.691763 555.715215
# Processing quantile index 56192: 486.770046 566.712879
# Processing quantile index 56256: 486.710293 439.357314
# Processing quantile index 56320: 486.653950 441.707649
# Processing quantile index 56384: 486.678301 509.094705
# Processing quantile index 56448: 486.459258 348.337448
# Processing quantile index 56512: 486.564843 601.763931
# Processing quantile index 56576: 486.642360 566.307580
# Processing quantile index 56640: 486.636246 481.291383
# Processing quantile index 56704: 486.610266 464.655944
# Processing quantile index 56768: 486.367467 337.268606
# Processing quantile index 56832: 486.116160 333.340936
# Processing quantile index 56896: 486.028605 419.012697
# Processing quantile index 56960: 481.814669 55.331670
# Processing quantile index 57024: 481.673425 382.006859
# Processing quantile index 57088: 481.647689 459.759970
# Processing quantile index 57152: 481.682347 514.720433
# Processing quantile index 57216: 481.768366 573.173424
# Processing quantile index 57280: 481.883633 613.002094
# Processing quantile index 57344: 481.866716 467.187959
# Processing quantile index 57408: 481.986818 620.575357
# Processing quantile index 57472: 482.078161 580.811635
# Processing quantile index 57536: 482.186632 604.287661
# Processing quantile index 57600: 482.142201 445.257417
# Processing quantile index 57664: 482.294553 673.963093
# Processing quantile index 57728: 482.210658 416.875086
# Processing quantile index 57792: 482.286189 561.636851
# Processing quantile index 57856: 482.263326 462.466523
# Processing quantile index 57920: 482.428597 698.968756
# Processing quantile index 57984: 482.471212 524.392469
# Processing quantile index 58048: 482.138178 296.630480
# Processing quantile index 58112: 482.316162 725.095571
# Processing quantile index 58176: 482.286991 457.180665
# Processing quantile index 58240: 482.388929 597.111058
# Processing quantile index 58304: 482.297344 411.246593
# Processing quantile index 58368: 482.410509 613.562549
# Processing quantile index 58432: 482.311499 406.266723
# Processing quantile index 58496: 482.374676 547.899024
# Processing quantile index 58560: 482.473809 594.059867
# Processing quantile index 58624: 482.519710 528.527576
# Processing quantile index 58688: 482.567791 531.039041
# Processing quantile index 58752: 482.654485 577.849701
# Processing quantile index 58816: 482.629220 460.500576
# Processing quantile index 58880: 482.738747 609.946116
# Processing quantile index 58944: 482.694301 445.000549
# Processing quantile index 59008: 482.832544 655.821124
# Processing quantile index 59072: 482.867974 517.907221
# Processing quantile index 59136: 483.035530 710.641150
# Processing quantile index 59200: 482.759997 316.135572
# Processing quantile index 59264: 482.908819 675.540452
# Processing quantile index 59328: 482.929112 502.482046
# Processing quantile index 59392: 482.861641 427.495367
# Processing quantile index 59456: 483.026711 707.466571
# Processing quantile index 59520: 482.954086 423.763381
# Processing quantile index 59584: 482.987386 516.080109
# Processing quantile index 59648: 483.028185 524.258306
# Processing quantile index 59712: 483.172857 670.275930
# Processing quantile index 59776: 483.207176 517.501853
# Processing quantile index 59840: 483.236758 512.543545
# Processing quantile index 59904: 483.213144 462.100309
# Processing quantile index 59968: 483.320297 609.912856
# Processing quantile index 60032: 483.404840 578.167073
# Processing quantile index 60096: 483.505340 600.635587
# Processing quantile index 60160: 483.575638 560.032746
# Processing quantile index 60224: 483.669662 591.839810
# Processing quantile index 60288: 483.036613 216.450706
# Processing quantile index 60352: 483.150089 620.454869
# Processing quantile index 60416: 483.122138 458.129454
# Processing quantile index 60480: 483.282544 703.904676
# Processing quantile index 60544: 483.319512 520.978970
# Processing quantile index 60608: 483.472860 690.821970
# Processing quantile index 60672: 483.395928 420.092045
# Processing quantile index 60736: 483.366232 456.765250
# Processing quantile index 60800: 483.399808 517.514823
# Processing quantile index 60864: 483.393674 477.635511
# Processing quantile index 60928: 483.193354 346.599546
# Processing quantile index 60992: 482.977082 338.668537
# Processing quantile index 61056: 483.054243 569.809309
# Processing quantile index 61120: 483.047213 476.432581
# Processing quantile index 61184: 483.002831 444.040660
# Processing quantile index 61248: 483.005858 485.917593
# Processing quantile index 61312: 482.884759 389.442138
# Processing quantile index 61376: 482.332541 230.169737
# Processing quantile index 61440: 482.410907 571.450526
# Processing quantile index 61504: 482.480821 560.456022
# Processing quantile index 61568: 482.493986 495.486859
# Processing quantile index 61632: 482.399627 406.014169
# Processing quantile index 61696: 482.568086 727.077221
# Processing quantile index 61760: 482.441959 385.350374
# Processing quantile index 61824: 482.543416 605.402472
# Processing quantile index 61888: 482.492351 437.743109
# Processing quantile index 61952: 482.618322 645.615866
# Processing quantile index 62016: 482.602106 467.400274
# Processing quantile index 62080: 482.400691 343.488786
# Processing quantile index 62144: 482.543808 677.518289
# Processing quantile index 62208: 482.530510 469.954965
# Processing quantile index 62272: 482.633384 608.791052
# Processing quantile index 62336: 482.612262 462.901158
# Processing quantile index 62400: 482.436205 355.958542
# Processing quantile index 62464: 481.771084 205.515774
# Processing quantile index 62528: 481.828719 545.524014
# Processing quantile index 62592: 481.928907 604.792769
# Processing quantile index 62656: 482.061319 659.193493
# Processing quantile index 62720: 482.173814 624.951589
# Processing quantile index 62784: 482.302276 652.724243
# Processing quantile index 62848: 482.354116 539.210005
# Processing quantile index 62912: 482.475985 641.681960
# Processing quantile index 62976: 482.482729 489.203866
# Processing quantile index 63040: 482.651171 735.222060
# Processing quantile index 63104: 482.668178 500.023202
# Processing quantile index 63168: 482.865781 809.723409
# Processing quantile index 63232: 482.847439 465.398702
# Processing quantile index 63296: 483.048440 820.514606

# %%
csvpath = "Test_tally.csv"
features = wholefeatures
print(features.shape)
units = features.shape[1]
print(units)
labels = len(data.label)
print(categories)
categories = data.category_names()
tally_both = np.zeros((units,labels),dtype=np.float64)
tally_units = np.zeros(units,dtype=np.float64)
tally_units_cat = np.zeros((units,len(categories)), dtype=np.float64)
tally_labels = np.zeros(labels,dtype=np.float64)
print(data.size)
# Out:
# (63305, 512, 7, 7)
# 512
# ['color', 'object', 'part', 'scene', 'texture']
# <bound method SegmentationData.size of <loader.data_loader.SegmentationData object at 0x7fa9cf054760>>
